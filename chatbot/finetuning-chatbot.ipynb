# %%
# %pip install streamlit
# %pip install streamlit-chat
# %pip install openai
# %pip install python-dotenv
# Out:
# Requirement already satisfied: streamlit in c:\users\lala5\anaconda3\envs\test\lib\site-packages (1.30.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (5.2.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (5.3.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: importlib-metadata<8,>=1.4 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (7.0.1)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (1.26.3)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (2.2.0)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (10.2.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=6.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (15.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (13.7.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (4.9.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (5.2)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (3.1.41)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (6.2)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit) (3.0.0)
# Requirement already satisfied: jinja2 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from altair<6,>=4.0->streamlit) (4.21.1)
# Requirement already satisfied: toolz in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: colorama in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from importlib-metadata<8,>=1.4->streamlit) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from requests<3,>=2.27->streamlit) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from requests<3,>=2.27->streamlit) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from requests<3,>=2.27->streamlit) (2023.11.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.17.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Collecting streamlit-chat
#   Downloading streamlit_chat-0.1.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: streamlit>=0.63 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit-chat) (1.30.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (5.2.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (5.3.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (8.1.7)
# Requirement already satisfied: importlib-metadata<8,>=1.4 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (7.0.1)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (1.26.3)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (2.2.0)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (10.2.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (3.20.3)
# Requirement already satisfied: pyarrow>=6.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (15.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (13.7.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (4.9.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (5.2)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (3.1.41)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (6.2)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from streamlit>=0.63->streamlit-chat) (3.0.0)
# Requirement already satisfied: jinja2 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from altair<6,>=4.0->streamlit>=0.63->streamlit-chat) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from altair<6,>=4.0->streamlit>=0.63->streamlit-chat) (4.21.1)
# Requirement already satisfied: toolz in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from altair<6,>=4.0->streamlit>=0.63->streamlit-chat) (0.12.1)
# Requirement already satisfied: colorama in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from click<9,>=7.0->streamlit>=0.63->streamlit-chat) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.63->streamlit-chat) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from importlib-metadata<8,>=1.4->streamlit>=0.63->streamlit-chat) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=0.63->streamlit-chat) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=0.63->streamlit-chat) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from python-dateutil<3,>=2.7.3->streamlit>=0.63->streamlit-chat) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit-chat) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit-chat) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit-chat) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit-chat) (2023.11.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from rich<14,>=10.14.0->streamlit>=0.63->streamlit-chat) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from rich<14,>=10.14.0->streamlit>=0.63->streamlit-chat) (2.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.63->streamlit-chat) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit>=0.63->streamlit-chat) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-chat) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-chat) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-chat) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-chat) (0.17.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=0.63->streamlit-chat) (0.1.2)
# Downloading streamlit_chat-0.1.1-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.2 MB 1.9 MB/s eta 0:00:01
#    -------------- ------------------------- 0.4/1.2 MB 6.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 0.9/1.2 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 7.7 MB/s eta 0:00:00
# Installing collected packages: streamlit-chat
# Successfully installed streamlit-chat-0.1.1
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openai in c:\users\lala5\anaconda3\envs\test\lib\site-packages (1.12.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from openai) (0.26.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from openai) (2.6.0)
# Requirement already satisfied: sniffio in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: idna>=2.8 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from httpx<1,>=0.23.0->openai) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.1 in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.16.1)
# Requirement already satisfied: colorama in c:\users\lala5\anaconda3\envs\test\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import openai
import streamlit
import os
import sys
import pandas as pd

openai.organization = "org-e3djfw9Vuf0b33C9eDUFgPms"
openai.api_key = "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"

# %%
prompts = """

Your name is '미리 Miri', and you play the role of Chatbot that answers defense-related information like a soldier in his 20s
You have to be very empathetic and kind.
You have to use "존댓말"

When you start the conversation, briefly introduce yourself and ask me questions about your questions.
You have to always answer in Korean and speak in honorifics like a male soldier in his 20s.
A new soldier in the military should operate as a chatbot to solve questions.

From now on, you will be conversing with the user following the steps below.
You MUST follow each step(Step 1 ~ Step 3) even when the user doesn't seem to have any stress!!

Step 1 : For Initial greeting, introduce yourself briefly with your name. Say "안녕하세요. 저는 국방 관련 정보를 제공하는 챗봇 미리입니다! 궁금한 것을 질문해주세요."
Step 2 : If you get a question, please refer to the explanation below and answer it.
Step 3 : Despite the above description, whenever the user says "고마워", just give "<대화가 종료되었습니다.>" and stop the conversation.

Only tasks that HELP learning, such as
1. 국방 관련 용어 뜻 알려주기 - Tell me the meaning of terms related to national defense
2. 군인과의 자연스러운 대화 나누기 - general common-sense conversations with army

"""

# %%
import streamlit as st
import openai

# OpenAI API 키 설정
openai.api_key = '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'

# ChatGPT에 대한 OpenAI Engine 설정
engine = "ft:gpt-3.5-turbo-1106:personal::8tErwhgv"

# 챗봇 대화 기록
conversation_history = []

# Streamlit 앱 제목 설정
st.title("ChatGPT 챗봇")

# 사용자 입력 받기
user_input = st.text_input("사용자 입력:")

# 사용자 입력이 있을 때만 챗봇 응답 생성
if user_input:
    # 사용자 입력과 이전 대화 기록을 결합하여 OpenAI에 전달
    prompt_text = "\n".join(conversation_history + [f"사용자: {user_input}", "챗봇:"])

    # OpenAI에 대화 요청 보내기
    response = openai.Completion.create(
        engine=engine,
        prompt=prompt_text,
        temperature=0.7,
        max_tokens=150
    )

    # 챗봇 응답 가져오기
    bot_reply = response.choices[0].text.strip()

    # 대화 기록에 사용자 입력과 챗봇 응답 추가
    conversation_history.append(f"사용자: {user_input}")
    conversation_history.append(f"챗봇: {bot_reply}")

    # 챗봇 응답 출력
    st.text_area("챗봇 응답:", value=bot_reply, height=150)

# %%
#inference용
import streamlit as st
import openai

# OpenAI API 키 설정
openai.api_key = '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'

completion = openai.ChatCompletion.create(
    model = "ft:gpt-3.5-turbo-1106:personal::8tErwhgv:ftjob-qlo74bgJqj2ei9ISSmgOBF6L",
    messages = [
        {"role": "system", "content" : "Miri is so kind chatbot."},
        {"role": "user", "content" : "안녕하세요. 흑룡에 대해 설명해주실래요?"}
    ]
)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[3], line 8
#       5 # OpenAI API 키 설정
#       6 openai.api_key = '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'
# ----> 8 completion = openai.ChatCompletion.create(
#       9     model = "ft:gpt-3.5-turbo-1106:personal::8tErwhgv:ftjob-qlo74bgJqj2ei9ISSmgOBF6L",
#      10     messages = [
#      11         {"role": "system", "content" : "Miri is so kind chatbot."},
#      12         {"role": "user", "content" : "안녕하세요. 흑룡에 대해 설명해주실래요?"}
#      13     ]
#      14 )
#
# File c:\Users\lala5\anaconda3\envs\test\lib\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File c:\Users\lala5\anaconda3\envs\test\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:155, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     129 @classmethod
#     130 def create(
#     131     cls,
#    (...)
#     138     **params,
#     139 ):
#     140     (
#     141         deployment_id,
#     142         engine,
#    (...)
#     152         api_key, api_base, api_type, api_version, organization, **params
#     153     )
# --> 155     response, _, api_key = requestor.request(
#     156         "post",
#     157         url,
#     158         params=params,
#     159         headers=headers,
#     160         stream=stream,
#     161         request_id=request_id,
#     162         request_timeout=request_timeout,
#     163     )
#     165     if stream:
#     166         # must be an iterator
#     167         assert not isinstance(response, OpenAIResponse)
#
# File c:\Users\lala5\anaconda3\envs\test\lib\site-packages\openai\api_requestor.py:299, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     278 def request(
#     279     self,
#     280     method,
#    (...)
#     287     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     288 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     289     result = self.request_raw(
#     290         method.lower(),
#     291         url,
#    (...)
#     297         request_timeout=request_timeout,
#     298     )
# --> 299     resp, got_stream = self._interpret_response(result, stream)
#     300     return resp, got_stream, self.api_key
#
# File c:\Users\lala5\anaconda3\envs\test\lib\site-packages\openai\api_requestor.py:710, in APIRequestor._interpret_response(self, result, stream)
#     702     return (
#     703         self._interpret_response_line(
#     704             line, result.status_code, result.headers, stream=True
#     705         )
#     706         for line in parse_stream(result.iter_lines())
#     707     ), True
#     708 else:
#     709     return (
# --> 710         self._interpret_response_line(
#     711             result.content.decode("utf-8"),
#     712             result.status_code,
#     713             result.headers,
#     714             stream=False,
#     715         ),
#     716         False,
#     717     )
#
# File c:\Users\lala5\anaconda3\envs\test\lib\site-packages\openai\api_requestor.py:775, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     773 stream_error = stream and "error" in resp.data
#     774 if stream_error or not 200 <= rcode < 300:
# --> 775     raise self.handle_error_response(
#     776         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     777     )
#     778 return resp
#
# InvalidRequestError: The model `ft:gpt-3.5-turbo-1106:personal::8tErwhgv:ftjob-qlo74bgJqj2ei9ISSmgOBF6L` does not exist
